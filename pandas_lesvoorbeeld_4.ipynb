# %% [markdown]
# # Pandas – Lesvoorbeeld 4.
#
# ## The Dataframe Data Structure

# %% [markdown]
# Dit notebook komt deels van de Coursera cursus
# Introduction to Data Science in Python - week 2
# University of Michigan

# %%
# importeren van de numpy en pandas bibliotheek; Pandas gebruikt numpy bij verwerkingen
import numpy as np
import pandas as pd

# %% [markdown]
# ## Multilevel index

# %% [markdown]
# Een multilevel index biedt de mogelijkheid om gemakkelijk groepen gegevens uit dataframe structuren te halen.
# Het is een manier om gegevens die toch meer dan 2 dimensies hebben toch overzichtelijk te verwerken.

# %%
# inlezen van bevolkingsgegevens van de USA
dfcs = pd.read_csv('pandas_census.csv')
dfcs.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# 1          7.242091         -2.915927         -3.012349          2.265971
# 2         14.832960         17.647293         21.845705         19.243287
# 3         -4.728132         -2.500690         -7.056824         -3.904217
# 4         -5.527043         -5.068871         -6.201001         -0.177537
#
#    RDOMESTICMIG2015  RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  \
# 0         -0.467369     1.030015     0.826644     1.383282     1.724718
# 1         -2.530799     7.606016    -2.626146    -2.722002     2.592270
# 2         17.197872    15.844176    18.559627    22.727626    20.317142
# 3        -10.543299    -4.874741    -2.758113    -7.167664    -3.978583
# 4          0.177258    -5.088389    -4.363636    -5.403729     0.754533
#
#    RNETMIG2015
# 0     0.712594
# 1    -2.187333
# 2    18.293499
# 3   -10.543299
# 4     1.107861
#
# [5 rows x 100 columns]

# %%
# SUMLEV is een aanduiding van het telnivau: 40=staatniveau, 50=plaatsniveau
dfcs['SUMLEV'].unique()
# Out:
# array([40, 50], dtype=int64)

# %%
# alleen de tellingen per plaats verzamelen
dfcs=dfcs[dfcs['SUMLEV'] == 50]
dfcs.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
# 5          57322              57322            57373     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 1          7.242091         -2.915927         -3.012349          2.265971
# 2         14.832960         17.647293         21.845705         19.243287
# 3         -4.728132         -2.500690         -7.056824         -3.904217
# 4         -5.527043         -5.068871         -6.201001         -0.177537
# 5          1.807375         -1.177622         -1.748766         -2.062535
#
#    RDOMESTICMIG2015  RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  \
# 1         -2.530799     7.606016    -2.626146    -2.722002     2.592270
# 2         17.197872    15.844176    18.559627    22.727626    20.317142
# 3        -10.543299    -4.874741    -2.758113    -7.167664    -3.978583
# 4          0.177258    -5.088389    -4.363636    -5.403729     0.754533
# 5         -1.369970     1.859511    -0.848580    -1.402476    -1.577232
#
#    RNETMIG2015
# 1    -2.187333
# 2    18.293499
# 3   -10.543299
# 4     1.107861
# 5    -0.884411
#
# [5 rows x 100 columns]

# %%
# De gegevens bestaat uit 100 kolommen, maar we zijn maar geïnteresseerd in enkele kolommen
columns_to_keep = ['STNAME',
                   'CTYNAME',
                   'BIRTHS2010',
                   'BIRTHS2011',
                   'BIRTHS2012',
                   'BIRTHS2013',
                   'BIRTHS2014',
                   'BIRTHS2015',
                   'POPESTIMATE2010',
                   'POPESTIMATE2011',
                   'POPESTIMATE2012',
                   'POPESTIMATE2013',
                   'POPESTIMATE2014',
                   'POPESTIMATE2015']
dfcs = dfcs[columns_to_keep]
dfcs.head()
# Out:
#     STNAME         CTYNAME  BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# 1  Alabama  Autauga County         151         636         615         574
# 2  Alabama  Baldwin County         517        2187        2092        2160
# 3  Alabama  Barbour County          70         335         300         283
# 4  Alabama     Bibb County          44         266         245         259
# 5  Alabama   Blount County         183         744         710         646
#
#    BIRTHS2014  BIRTHS2015  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 1         623         600            54660            55253            55175
# 2        2186        2240           183193           186659           190396
# 3         260         269            27341            27226            27159
# 4         247         253            22861            22733            22642
# 5         618         603            57373            57711            57776
#
#    POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015
# 1            55038            55290            55347
# 2           195126           199713           203709
# 3            26973            26815            26489
# 4            22512            22549            22583
# 5            57734            57658            57673

# %%
# nu gaan we een meer-niveau index toevoegen
dfcs = dfcs.set_index(['STNAME', 'CTYNAME'])
dfcs.head()
# Out:
#                         BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME  CTYNAME
# Alabama Autauga County         151         636         615         574
#         Baldwin County         517        2187        2092        2160
#         Barbour County          70         335         300         283
#         Bibb County             44         266         245         259
#         Blount County          183         744         710         646
#
#                         BIRTHS2014  BIRTHS2015  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Autauga County         623         600            54660
#         Baldwin County        2186        2240           183193
#         Barbour County         260         269            27341
#         Bibb County            247         253            22861
#         Blount County          618         603            57373
#
#                         POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME  CTYNAME
# Alabama Autauga County            55253            55175            55038
#         Baldwin County           186659           190396           195126
#         Barbour County            27226            27159            26973
#         Bibb County               22733            22642            22512
#         Blount County             57711            57776            57734
#
#                         POPESTIMATE2014  POPESTIMATE2015
# STNAME  CTYNAME
# Alabama Autauga County            55290            55347
#         Baldwin County           199713           203709
#         Barbour County            26815            26489
#         Bibb County               22549            22583
#         Blount County             57658            57673

# %%
# Nu kunnen we op de combinatie-index gegevens opvragen
dfcs.loc[('Michigan', 'Washtenaw County')]
# Out:
# BIRTHS2010            977
# BIRTHS2011           3826
# BIRTHS2012           3780
# BIRTHS2013           3662
# BIRTHS2014           3683
# BIRTHS2015           3709
# POPESTIMATE2010    345563
# POPESTIMATE2011    349048
# POPESTIMATE2012    351213
# POPESTIMATE2013    354289
# POPESTIMATE2014    357029
# POPESTIMATE2015    358880
# Name: (Michigan, Washtenaw County), dtype: int64

# %%
# ook nu kunnen we een reeks rijen en daarvan bepaalde kolommen opvragen
dfcs.loc[ [('Michigan', 'Washtenaw County'),('Michigan', 'Wayne County')],['POPESTIMATE2010','POPESTIMATE2015']]
# Out:
#                            POPESTIMATE2010  POPESTIMATE2015
# STNAME   CTYNAME
# Michigan Washtenaw County           345563           358880
#          Wayne County              1815199          1759335

# %% [markdown]
# ## Krachtige functieverwerking op dataframe rij niveau

# %%
# definitie van een python functie die een minimale en maximale waarde van het bevolkingsaantal bepaald
def min_max(row):
    data = row[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    return pd.Series({'min': np.min(data), 'max': np.max(data)})

# %%
# de gedefinieerde functie op elke rij van de dataset uit laten voeren
dfcsmm = dfcs.apply(min_max, axis=1)
dfcsmm.head()
# Out:
#                            min     max
# STNAME  CTYNAME
# Alabama Autauga County   54660   55347
#         Baldwin County  183193  203709
#         Barbour County   26489   27341
#         Bibb County      22512   22861
#         Blount County    57373   57776

# %%
# definitie van een functie die 2 kolommen toevoegt aan de oorspronkelijke rijen
def min_max_2(row):
    data = row[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    row['POPESTIMATEMAX'] = np.max(data)  # extra column
    row['POPESTIMATEMIN'] = np.min(data)  # extra column
    return row
dfcsmm2 = dfcs.apply(min_max_2, axis=1)
dfcsmm2.head()
# Out:
#                         BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME  CTYNAME
# Alabama Autauga County         151         636         615         574
#         Baldwin County         517        2187        2092        2160
#         Barbour County          70         335         300         283
#         Bibb County             44         266         245         259
#         Blount County          183         744         710         646
#
#                         BIRTHS2014  BIRTHS2015  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Autauga County         623         600            54660
#         Baldwin County        2186        2240           183193
#         Barbour County         260         269            27341
#         Bibb County            247         253            22861
#         Blount County          618         603            57373
#
#                         POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME  CTYNAME
# Alabama Autauga County            55253            55175            55038
#         Baldwin County           186659           190396           195126
#         Barbour County            27226            27159            26973
#         Bibb County               22733            22642            22512
#         Blount County             57711            57776            57734
#
#                         POPESTIMATE2014  POPESTIMATE2015  POPESTIMATEMAX  \
# STNAME  CTYNAME
# Alabama Autauga County            55290            55347           55347
#         Baldwin County           199713           203709          203709
#         Barbour County            26815            26489           27341
#         Bibb County               22549            22583           22861
#         Blount County             57658            57673           57776
#
#                         POPESTIMATEMIN
# STNAME  CTYNAME
# Alabama Autauga County           54660
#         Baldwin County          183193
#         Barbour County           26489
#         Bibb County              22512
#         Blount County            57373

# %% [markdown]
# # Group by

# %% [markdown]
# Group by biedt krachtige verwerkingen om een grote verzameling gegevens per groep te analyseren. (Dit is een beetje vergelijkbaar met de SQL GROUP BY mogelijkheid)

# %%
# Het bepalen van het gemiddeld aantal geboren kinderen per staat van alle steden in de staat
dfcs.groupby('STNAME')['BIRTHS2015'].agg(['mean'])
# Out:
#                              mean
# STNAME
# Alabama                870.223881
# Alaska                 396.482759
# Arizona               5825.666667
# Arkansas               504.266667
# California            8687.051724
# Colorado              1047.765625
# Connecticut           4528.125000
# Delaware              3677.666667
# District of Columbia  9593.000000
# Florida               3292.955224
# Georgia                821.333333
# Hawaii                3859.600000
# Idaho                  517.068182
# Illinois              1533.725490
# Indiana                910.826087
# Iowa                   398.686869
# Kansas                 370.990476
# Kentucky               464.091667
# Louisiana              992.421875
# Maine                  802.312500
# Maryland              3031.416667
# Massachusetts         5221.714286
# Michigan              1379.771084
# Minnesota              802.896552
# Mississippi            470.097561
# Missouri               657.034783
# Montana                224.875000
# Nebraska               282.322581
# Nevada                2119.764706
# New Hampshire         1256.200000
# New Jersey            4905.047619
# New Mexico             796.545455
# New York              3852.112903
# North Carolina        1206.760000
# North Dakota           210.754717
# Ohio                  1589.590909
# Oklahoma               700.857143
# Oregon                1280.305556
# Pennsylvania          2118.746269
# Rhode Island          2196.800000
# South Carolina        1258.804348
# South Dakota           187.030303
# Tennessee              855.378947
# Texas                 1567.275591
# Utah                  1776.413793
# Vermont                427.214286
# Virginia               777.120301
# Washington            2276.461538
# West Virginia          377.527273
# Wisconsin              928.597222
# Wyoming                334.565217

# %%
dfcs.head()
# Out:
#                         BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME  CTYNAME
# Alabama Autauga County         151         636         615         574
#         Baldwin County         517        2187        2092        2160
#         Barbour County          70         335         300         283
#         Bibb County             44         266         245         259
#         Blount County          183         744         710         646
#
#                         BIRTHS2014  BIRTHS2015  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Autauga County         623         600            54660
#         Baldwin County        2186        2240           183193
#         Barbour County         260         269            27341
#         Bibb County            247         253            22861
#         Blount County          618         603            57373
#
#                         POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME  CTYNAME
# Alabama Autauga County            55253            55175            55038
#         Baldwin County           186659           190396           195126
#         Barbour County            27226            27159            26973
#         Bibb County               22733            22642            22512
#         Blount County             57711            57776            57734
#
#                         POPESTIMATE2014  POPESTIMATE2015
# STNAME  CTYNAME
# Alabama Autauga County            55290            55347
#         Baldwin County           199713           203709
#         Barbour County            26815            26489
#         Bibb County               22549            22583
#         Blount County             57658            57673

# %%
# Ook meerdere berekeningen kunnen gezamenlijk
dfcs.groupby(level=0)['BIRTHS2015'].agg(['mean','sum','min','max'])
# (Hier wordt de index met behulp van een level aangeduidt: level 0 is 'STNAME')
# Out:
#                              mean     sum   min     max
# STNAME
# Alabama                870.223881   58305    89    8639
# Alaska                 396.482759   11498     8    4796
# Arizona               5825.666667   87385   143   55671
# Arkansas               504.266667   37820    48    5514
# California            8687.051724  503849     4  130070
# Colorado              1047.765625   67057     4   10104
# Connecticut           4528.125000   36225  1104   10078
# Delaware              3677.666667   11033  2196    6585
# District of Columbia  9593.000000    9593  9593    9593
# Florida               3292.955224  220628    67   31534
# Georgia                821.333333  130592    15   13096
# Hawaii                3859.600000   19298     0   13789
# Idaho                  517.068182   22751     8    5128
# Illinois              1533.725490  156440    22   68855
# Indiana                910.826087   83796    53   14487
# Iowa                   398.686869   39470    53    6951
# Kansas                 370.990476   38954    18    7575
# Kentucky               464.091667   55691    17   10000
# Louisiana              992.421875   63515    65    6140
# Maine                  802.312500   12837   137    2951
# Maryland              3031.416667   72754   177   13106
# Massachusetts         5221.714286   73104   133   17850
# Michigan              1379.771084  114521    15   23586
# Minnesota              802.896552   69852    32   16891
# Mississippi            470.097561   38548    14    3249
# Missouri               657.034783   75559    24   11673
